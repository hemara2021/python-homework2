# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
sp500_history_path = Path("Resources/sp500_history.csv")
sp500_history = pd.read_csv(sp500_history_path)

whale_returns_path = Path("Resources/whale_returns.csv")
whale_returns = pd.read_csv(whale_returns_path)
whale_returns.head()
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
whale_returns.isnull()
# Out:
#        Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     False                       True                True
# 1     False                      False               False
# 2     False                      False               False
# 3     False                      False               False
# 4     False                      False               False
# ...     ...                        ...                 ...
# 1055  False                      False               False
# 1056  False                      False               False
# 1057  False                      False               False
# 1058  False                      False               False
# 1059  False                      False               False
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                            True                    True
# 1                           False                   False
# 2                           False                   False
# ...

# %%
whale_returns.dtypes
# Out:
# Date                            object
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
whale_returns['Date']= pd.to_datetime(whale_returns['Date'])
whale_returns.dtypes
# Out:
# Date                           datetime64[ns]
# SOROS FUND MANAGEMENT LLC             float64
# PAULSON & CO.INC.                     float64
# TIGER GLOBAL MANAGEMENT LLC           float64
# BERKSHIRE HATHAWAY INC                float64
# dtype: object

# %%
# Drop nulls
whale_returns_final = whale_returns.dropna()
whale_returns_final.head()
# Out:
#         Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1 2015-03-03                  -0.001266           -0.004981
# 2 2015-03-04                   0.002230            0.003241
# 3 2015-03-05                   0.004016            0.004076
# 4 2015-03-06                  -0.007905           -0.003574
# 5 2015-03-09                   0.000582            0.004225
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098
# 5                     0.005843               -0.001652

# %%
whale_returns_final.set_index(pd.to_datetime(whale_returns_final['Date'], infer_datetime_format=True), inplace=True)
whale_returns_final.drop(columns=['Date'], inplace=True)
whale_returns_final.head()
# Out:
# C:\Users\hany_\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# ...

# %%
whale_returns.dtypes
# Out:
# Date                           datetime64[ns]
# SOROS FUND MANAGEMENT LLC             float64
# PAULSON & CO.INC.                     float64
# TIGER GLOBAL MANAGEMENT LLC           float64
# BERKSHIRE HATHAWAY INC                float64
# dtype: object

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_path = Path("Resources/algo_returns.csv")
algo_returns = pd.read_csv(algo_returns_path)
algo_returns.tail()
# Out:
#             Date    Algo 1    Algo 2
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358

# %%
algo_returns.dtypes
# Out:
# Date       object
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %%
algo_returns['Date']= pd.to_datetime(algo_returns['Date'])
algo_returns.dtypes
# Out:
# Date      datetime64[ns]
# Algo 1           float64
# Algo 2           float64
# dtype: object

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
algo_returns.isnull()
# Out:
#        Date  Algo 1  Algo 2
# 0     False   False    True
# 1     False   False    True
# 2     False   False    True
# 3     False   False    True
# 4     False   False    True
# ...     ...     ...     ...
# 1236  False   False   False
# 1237  False   False   False
# 1238  False   False   False
# 1239  False   False   False
# 1240  False   False   False
#
# [1241 rows x 3 columns]

# %%
# Drop nulls
algo_daily_final_returns = algo_returns.dropna(subset=['Algo 1', 'Algo 2'])
algo_daily_final_returns.tail()
# Out:
#            Date    Algo 1    Algo 2
# 1236 2019-04-25  0.000682 -0.007247
# 1237 2019-04-26  0.002981  0.005256
# 1238 2019-04-29  0.005208  0.002829
# 1239 2019-04-30 -0.002944 -0.001570
# 1240 2019-05-01  0.000094 -0.007358

# %%
algo_daily_final_returns.dtypes
# Out:
# Date      datetime64[ns]
# Algo 1           float64
# Algo 2           float64
# dtype: object

# %%
algo_daily_final_returns.set_index(pd.to_datetime(algo_daily_final_returns['Date'], infer_datetime_format=True), inplace=True)
algo_daily_final_returns.drop(columns=['Date'], inplace=True)
algo_daily_final_returns.head()
# Out:
# C:\Users\hany_\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
algo_daily_final_returns.dtypes
# Out:
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %%
columns = ["Algo 1_Return", "Algo 2_Return"]
algo_daily_final_returns.columns = columns
algo_daily_final_returns.head()
# Out:
#             Algo 1_Return  Algo 2_Return
# Date
# 2014-06-05       0.004062       0.013285
# 2014-06-06       0.001857       0.008284
# 2014-06-09      -0.005012       0.005668
# 2014-06-10       0.004406      -0.000735
# 2014-06-11       0.004760      -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_path = Path("Resources/sp500_history.csv")
sp500_history = pd.read_csv(sp500_history_path)
sp500_history.tail()
# Out:
#           Date     Close
# 1644  5-Oct-12  $1460.93
# 1645  4-Oct-12  $1461.40
# 1646  3-Oct-12  $1450.99
# 1647  2-Oct-12  $1445.75
# 1648  1-Oct-12  $1444.49

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history['Close'] = sp500_history['Close'].str.replace('$', '')
sp500_history['Date']= pd.to_datetime(sp500_history['Date'])
sp500_history.head()
# Out:
# <ipython-input-22-d14266cf527b>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   sp500_history['Close'] = sp500_history['Close'].str.replace('$', '')
#         Date    Close
# 0 2019-04-23  2933.68
# 1 2019-04-22  2907.97
# 2 2019-04-18  2905.03
# 3 2019-04-17  2900.45
# 4 2019-04-16  2907.06

# %%
sp500_history.dtypes
# Out:
# Date     datetime64[ns]
# Close            object
# dtype: object

# %%
sp500_history['Close'] = pd.to_numeric(sp500_history['Close'])
sp500_history.dtypes
# Out:
# Date     datetime64[ns]
# Close           float64
# dtype: object

# %%
sp500_history.set_index(pd.to_datetime(sp500_history['Date'], infer_datetime_format=True), inplace=True)
sp500_history.drop(columns=['Date'], inplace=True)
sp500_history.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500_history.pct_change()
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
sp500_daily_final_returns = sp500_daily_returns.dropna()
sp500_daily_final_returns.head()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
# Rename `Close` Column to be specific to this portfolio.
columns = ["S&P_500_Return"]
sp500_daily_final_returns.columns = columns
sp500_daily_final_returns.head()
# Out:
#             S&P_500_Return
# Date
# 2019-04-22       -0.008764
# 2019-04-18       -0.001011
# 2019-04-17       -0.001577
# 2019-04-16        0.002279
# 2019-04-15       -0.000509

# %%
combined_return = pd.concat([whale_returns_final, algo_daily_final_returns, sp500_daily_final_returns], axis="columns", join="inner")
combined_return.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  \
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
#
#             Algo 1_Return  Algo 2_Return  S&P_500_Return
# Date
# 2015-03-03      -0.001942      -0.000949        0.004408
# 2015-03-04      -0.008589       0.002416       -0.001195
# ...

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
combined_return.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# Algo 1_Return                  float64
# Algo 2_Return                  float64
# S&P_500_Return                 float64
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_return.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + combined_return).cumprod() - 1
# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_return.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_mean = combined_return.mean()
combined_std = combined_return.std()
combined_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1_Return                  0.007623
# dtype: float64

# %%
combined_mean.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.000171
# PAULSON & CO.INC.             -0.000217
# TIGER GLOBAL MANAGEMENT LLC   -0.000089
# BERKSHIRE HATHAWAY INC         0.000494
# Algo 1_Return                  0.000658
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
combined_std.tail(1)
# Out:
# S&P_500_Return    0.008587
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
combined_std = combined_std.sort_values(ascending=False)
combined_std.head(10)
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# S&P_500_Return                 0.008587
# Algo 2_Return                  0.008341
# SOROS FUND MANAGEMENT LLC      0.007896
# Algo 1_Return                  0.007623
# PAULSON & CO.INC.              0.007026
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = combined_std * np.sqrt(252)
annualized_std.head()
# Out:
# BERKSHIRE HATHAWAY INC         0.205079
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# S&P_500_Return                 0.136313
# Algo 2_Return                  0.132413
# SOROS FUND MANAGEMENT LLC      0.125348
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_std_21 = combined_return.rolling(window=21).std()
# Plot the rolling standard deviation
combined_std_21.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = combined_return.corr()
# Display de correlation matrix
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1_Return                                 0.320901            0.268631
# Algo 2_Return                                 0.826730            0.678085
# S&P_500_Return                                0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1_Return                                   0.164114
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
soros_covariance = combined_return['SOROS FUND MANAGEMENT LLC'].cov(combined_return['S&P_500_Return'])
paulson_covariance = combined_return['PAULSON & CO.INC. '].cov(combined_return['S&P_500_Return'])
tiger_covariance = combined_return['TIGER GLOBAL MANAGEMENT LLC'].cov(combined_return['S&P_500_Return'])
berkshire_covariance = combined_return['BERKSHIRE HATHAWAY INC'].cov(combined_return['S&P_500_Return'])
algo_1_covariance = combined_return['Algo 1_Return'].cov(combined_return['S&P_500_Return'])
algo_2_covariance = combined_return['Algo 2_Return'].cov(combined_return['S&P_500_Return'])
# Calculate variance of S&P 500
variance_sp = combined_return['S&P_500_Return'].var()
# Computing beta
soros_beta = soros_covariance / variance_sp
paulson_beta = paulson_covariance / variance_sp
tiger_beta = tiger_covariance / variance_sp
berkshire_beta = berkshire_covariance / variance_sp
algo_1_beta = algo_1_covariance / variance_sp
algo_2_beta = algo_2_covariance / variance_sp
# Plot beta trend
berkshire_covariance_21 = combined_return['BERKSHIRE HATHAWAY INC'].rolling(window=21).cov(combined_return['S&P_500_Return'])
variance_21 = combined_return['S&P_500_Return'].rolling(window=21).var()
berkshire_beta_21 = berkshire_covariance_21 / variance_21
berkshire_beta_21.plot(figsize=(20, 10), title='Rolling 30-Day Beta of BERKSHIRE HATHAWAY INC')
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Beta of BERKSHIRE HATHAWAY INC'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
combined_return['BERKSHIRE HATHAWAY INC'].ewm(span=21, adjust=False).mean()
# Out:
# Date
# 2015-03-03   -0.006569
# 2015-03-04   -0.005589
# 2015-03-05   -0.004469
# 2015-03-06   -0.005253
# 2015-03-09   -0.004926
#                 ...
# 2019-04-15    0.001321
# 2019-04-16    0.001277
# 2019-04-17    0.001454
# 2019-04-18    0.001496
# 2019-04-22    0.001261
# Name: BERKSHIRE HATHAWAY INC, Length: 1042, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = ((combined_return.mean()) * 252) / (combined_return.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1_Return                  1.369589
# Algo 2_Return                  0.484334
# S&P_500_Return                -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
aapl_historical_path = Path("Resources/aapl_historical.csv")
aapl_historical = pd.read_csv(aapl_historical_path)
aapl_historical['Trade DATE']= pd.to_datetime(aapl_historical['Trade DATE'])
aapl_historical.dtypes
# Out:
# Symbol                object
# Trade DATE    datetime64[ns]
# NOCP                 float64
# dtype: object

# %%
aapl_historical.set_index(pd.to_datetime(aapl_historical['Trade DATE'], infer_datetime_format=True), inplace=True)
aapl_historical.drop(columns=['Trade DATE', 'Symbol'], inplace=True)
columns = ["aapl_price"]
aapl_historical.columns = columns
aapl_historical.head()
# Out:
#             aapl_price
# Trade DATE
# 2019-05-09      200.72
# 2019-05-08      202.90
# 2019-05-07      202.86
# 2019-05-06      208.48
# 2019-05-03      211.75

# %%
aapl_historical_return = aapl_historical.pct_change().dropna()
aapl_historical_return.head()
# Out:
#             aapl_price
# Trade DATE
# 2019-05-08    0.010861
# 2019-05-07   -0.000197
# 2019-05-06    0.027704
# 2019-05-03    0.015685
# 2019-05-02   -0.012279

# %%
# Reading data from 2nd stock
cost_historical_path = Path("Resources/cost_historical.csv")
cost_historical = pd.read_csv(cost_historical_path)
cost_historical['Trade DATE']= pd.to_datetime(cost_historical['Trade DATE'])
cost_historical.dtypes
# Out:
# Symbol                object
# Trade DATE    datetime64[ns]
# NOCP                 float64
# dtype: object

# %%
cost_historical.set_index(pd.to_datetime(cost_historical['Trade DATE'], infer_datetime_format=True), inplace=True)
cost_historical.drop(columns=['Trade DATE', 'Symbol'], inplace=True)
columns = ["cost_price"]
cost_historical.columns = columns
cost_historical.head()
# Out:
#             cost_price
# Trade DATE
# 2019-05-09      243.47
# 2019-05-08      241.34
# 2019-05-07      240.18
# 2019-05-06      244.23
# 2019-05-03      244.62

# %%
cost_historical_return = cost_historical.pct_change().dropna()
cost_historical_return.head()
# Out:
#             cost_price
# Trade DATE
# 2019-05-08   -0.008749
# 2019-05-07   -0.004806
# 2019-05-06    0.016862
# 2019-05-03    0.001597
# 2019-05-02   -0.007890

# %%
# Reading data from 3rd stock
goog_historical_path = Path("Resources/cost_historical.csv")
goog_historical = pd.read_csv(goog_historical_path)
goog_historical['Trade DATE']= pd.to_datetime(goog_historical['Trade DATE'])
goog_historical.dtypes
# Out:
# Symbol                object
# Trade DATE    datetime64[ns]
# NOCP                 float64
# dtype: object

# %%
goog_historical.set_index(pd.to_datetime(goog_historical['Trade DATE'], infer_datetime_format=True), inplace=True)
goog_historical.drop(columns=['Trade DATE', 'Symbol'], inplace=True)
columns = ["goog_price"]
goog_historical.columns = columns
goog_historical.head()
# Out:
#             goog_price
# Trade DATE
# 2019-05-09      243.47
# 2019-05-08      241.34
# 2019-05-07      240.18
# 2019-05-06      244.23
# 2019-05-03      244.62

# %%
goog_historical_return = goog_historical.pct_change().dropna()
goog_historical_return.head()
# Out:
#             goog_price
# Trade DATE
# 2019-05-08   -0.008749
# 2019-05-07   -0.004806
# 2019-05-06    0.016862
# 2019-05-03    0.001597
# 2019-05-02   -0.007890

# %%
combined_all_return = pd.concat([aapl_historical_return, cost_historical_return, goog_historical_return], axis="columns", join="inner")
combined_all_return.head()
# Out:
#             aapl_price  cost_price  goog_price
# Trade DATE
# 2019-05-08    0.010861   -0.008749   -0.008749
# 2019-05-07   -0.000197   -0.004806   -0.004806
# 2019-05-06    0.027704    0.016862    0.016862
# 2019-05-03    0.015685    0.001597    0.001597
# 2019-05-02   -0.012279   -0.007890   -0.007890

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_returns = combined_all_return.dot(weights)

# Display sample data
portfolio_returns.head()
# Out:
# Trade DATE
# 2019-05-08   -0.002212
# 2019-05-07   -0.003270
# 2019-05-06    0.020476
# 2019-05-03    0.006293
# 2019-05-02   -0.009353
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_all_return['Pro_rata_return'] = portfolio_returns
combined_all_return.head()
# Out:
#             aapl_price  cost_price  goog_price  Pro_rata_return
# Trade DATE
# 2019-05-08    0.010861   -0.008749   -0.008749        -0.002212
# 2019-05-07   -0.000197   -0.004806   -0.004806        -0.003270
# 2019-05-06    0.027704    0.016862    0.016862         0.020476
# 2019-05-03    0.015685    0.001597    0.001597         0.006293
# 2019-05-02   -0.012279   -0.007890   -0.007890        -0.009353

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_all_return_final = combined_all_return.dropna()
combined_all_return_final.tail()
# Out:
#             aapl_price  cost_price  goog_price  Pro_rata_return
# Trade DATE
# 2018-05-17    0.003650    0.003217    0.003217         0.003361
# 2018-05-16    0.006364   -0.004459   -0.004459        -0.000851
# 2018-05-15   -0.009246   -0.016255   -0.016255        -0.013919
# 2018-05-14    0.009172    0.002046    0.002046         0.004421
# 2018-05-11    0.002339   -0.000613   -0.000613         0.000371

# %%
combined_std_all = combined_all_return_final.std()
combined_std_all = combined_std_all.sort_values(ascending=False)
combined_std.head(10)
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# S&P_500_Return                 0.008587
# Algo 2_Return                  0.008341
# SOROS FUND MANAGEMENT LLC      0.007896
# Algo 1_Return                  0.007623
# PAULSON & CO.INC.              0.007026
# dtype: float64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_std_all = combined_std_all * np.sqrt(252)
annualized_std_all.head()
# Out:
# aapl_price         0.300387
# cost_price         0.213344
# goog_price         0.213344
# Pro_rata_return    0.205051
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
combined_std_21_all = combined_all_return_final.rolling(window=21).std()
# Plot rolling standard deviation
combined_std_21_all.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Trade DATE'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation_all = combined_all_return_final.corr()
# Display de correlation matrix
correlation_all
# Out:
#                  aapl_price  cost_price  goog_price  Pro_rata_return
# aapl_price         1.000000    0.413964    0.413964         0.775452
# cost_price         0.413964    1.000000    1.000000         0.895774
# goog_price         0.413964    1.000000    1.000000         0.895774
# Pro_rata_return    0.775452    0.895774    0.895774         1.000000

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
Pro_rata_return_60 = combined_all_return_final['Pro_rata_return'].rolling(window=60).cov(combined_return['S&P_500_Return'])
variance_60 = combined_return['S&P_500_Return'].rolling(window=60).var()
Pro_rata_return_beta_60 = Pro_rata_return_60  / variance_60
Pro_rata_return_beta_60.plot(figsize=(20, 10), title='Rolling 60-Day Beta of Pro_rata_return')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of Pro_rata_return'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
sharpe_ratios_all = ((combined_all_return_final.mean()) * 252) / (combined_all_return_final.std() * np.sqrt(252))
sharpe_ratios_all
# Out:
# aapl_price        -0.061751
# cost_price        -0.929405
# goog_price        -0.929405
# Pro_rata_return   -0.674817
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_all.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
print("Portfolio has been performing better than the individual stocks historically")
# Out:
# Portfolio has been performing better than the individual stocks historically
